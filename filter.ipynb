# %% [markdown]
# Buscar colunas pelo método filter

# %%
import pandas as pd

df = pd.read_csv('produtos.csv')
df.head()
# Out:
#        codigo       marca    tipo  categoria  preco_unitario  custo  \
# 0  MOLO000251    Logitech   Mouse          1           25.95    6.5
# 1  MOLO000192    Logitech   Mouse          2           19.95    5.0
# 2  CAHA000251     Hashtag  Camisa          1           25.00   11.0
# 3  CAHA000252     Hashtag  Camisa          2           25.00   11.0
# 4  MOMU000111  Multilaser   Mouse          1           11.99    3.4
#
#                 obs
# 0               NaN
# 1               NaN
# 2               NaN
# 3  Conferir estoque
# 4               NaN

# %% [markdown]
# Neste caso está buscando colunas que contém a letra "o"

# %%
df.filter(like='o')
# Out:
#          codigo        tipo  categoria  preco_unitario  custo  \
# 0    MOLO000251       Mouse          1           25.95    6.5
# 1    MOLO000192       Mouse          2           19.95    5.0
# 2    CAHA000251      Camisa          1           25.00   11.0
# 3    CAHA000252      Camisa          2           25.00   11.0
# 4    MOMU000111       Mouse          1           11.99    3.4
# ..          ...         ...        ...             ...    ...
# 288  ACAP000192  Acessorios          2           19.00    3.8
# 289  ACSA0009.3  Acessorios          3            9.55    2.1
# 290  CEMO000271     Celular          1          279.00   72.5
# 291  FOMO000152        Fone          2          150.00   33.0
# 292  CEMO000223     Celular          3          229.00   55.0
#
#                   obs
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3    Conferir estoque
# 4                 NaN
# ..                ...
# 288               NaN
# 289               NaN
# ...
